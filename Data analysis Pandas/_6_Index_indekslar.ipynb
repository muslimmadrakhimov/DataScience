# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df = pd.DataFrame(data, columns=['Yil', 'Aholi soni', 'Temp', 'YAIM'])
df
# Out:
#     Yil  Aholi soni  Temp YAIM
# 0  2021        33.9  1.54  NaN
# 1  2020        33.5  1.48  NaN
# 2  2019        32.9  1.56  NaN
# 3  2018        32.5  1.62  NaN
# 4  2017        31.9  1.65  NaN
# 5  2016        31.4  1.66  NaN
# 6  2015        30.9  1.64  NaN
# 7  2010        28.5  1.53  NaN

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'])
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'], index=[21, 20, 19, 18, 17, 16, 15, 10])
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
val = [1700, 1670, 1650, 1590, 1400, 1300, 1350, 1360]
df.YAIM = val
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1650
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1650
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %% [markdown]
# INDEX OBYEKTI

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1650
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
# indekslarni kōrish
df.index
# Out:
# Index([21, 20, 19, 18, 17, 16, 15, 10], dtype='int64')

# %%
# Ustunlarni kōrish
df.columns
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
# Alohida ōzgaruvchiga saqlab olish
indeks = df.columns
indeks
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
# Saqlab olingan ōzgaruvchi orqali ustunlarni tekshirib olish usuli
'Temp' in indeks
# Out:
# True

# %%
'Aholi soni' in indeks
# Out:
# True

# %%
# Lugatdan DataFrame yaratganda lugatdagi kalitlar index ōrnida keladi(2021, 2020 va hokazo...)
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df2 = pd.DataFrame(data)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %% [markdown]
# Ustunlarni orasida malumot bor yoki yoqligini tekshirib kōrish usuli

# %%
'Tajikistan' in df2.columns
# Out:
# False

# %% [markdown]
# Indekslar orasida malumot bor yoki yoqligini tekshirib kōrish usuli

# %%
2021 in df2.index
# Out:
# True

# %% [markdown]
# Indekslarga tartib raqami bōyicha ham murojat qilish

# %%
indeks
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks[0] # bu erda 0 chi ustun 'Yil' chiqadi
# Out:
# 'Yil'

# %%
indeks[2:4]
# Out:
# Index(['Aholi soni', 'YAIM'], dtype='object')
