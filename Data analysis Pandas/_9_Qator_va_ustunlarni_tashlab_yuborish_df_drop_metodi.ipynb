# %%
import pandas as pd
import numpy as np

# %%
data = {'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
        'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
        'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
        'Zichlik':[79.77, 78.68, 77.53, 76.34, 75.13, 73.91, 72.71, 67.03]}
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.48    78.68
# 2  2019        32.9  1.56    77.53
# 3  2018        32.5  1.62    76.34
# 4  2017        31.9  1.65    75.13
# 5  2016        31.4  1.66    73.91
# 6  2015        30.9  1.64    72.71
# 7  2010        28.5  1.53    67.03

# %%
df.index = [21, 20, 19, 18, 17, 16, 15, 10]
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.48    78.68
# 19  2019        32.9  1.56    77.53
# 18  2018        32.5  1.62    76.34
# 17  2017        31.9  1.65    75.13
# 16  2016        31.4  1.66    73.91
# 15  2015        30.9  1.64    72.71
# 10  2010        28.5  1.53    67.03

# %%
# Reindex
ind = [21, 20, 19, 18, 17, 16, 15, 10]
# rōyhatni tartiblash
ind.sort()
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df = df.reindex(ind)
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %% [markdown]
# Qatorlarni tashlab yoborish

# %%
df2 = df.drop(10)
df2
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
# bir nechta qatorlarni tashlab yuborish
df.drop([15, 20])
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 21  2021        33.9  1.54    79.77

# %% [markdown]
# Ustunlarni tashlab yuborish

# %%
df.drop('Yil', axis=1) # birinchi usuli
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77

# %%
df.drop('Yil', axis='columns') # ikkinchi usuli
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77

# %%
df # bu yerda asosiy DataFrame ōzgarmayapti
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    67.03
# 15  2015        30.9  1.64    72.71
# 16  2016        31.4  1.66    73.91
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.34
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
# Data Frame ōzida joyida saqlab qolishni birinchi usuli
df.drop('Yil', axis='columns', inplace=True)

# %%
# ōzgartirilgan DataFrame ni saqlash usuli
df_new = df.drop('Yil', axis='columns') # ikkinchi usuli
df_new
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    67.03
# 15        30.9  1.64    72.71
# 16        31.4  1.66    73.91
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.34
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77
