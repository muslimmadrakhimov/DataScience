# %%
import pandas as pd

# %%
data = {
    'Yil':[2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %% [markdown]
# DataFrame ustunlari nomini ōzgartirish

# %%
# columns
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni'])
df.head()
# Out:
#     Yil  Temp  Aholi soni
# 0  2021  1.54        33.9
# 1  2020  1.48        33.5
# 2  2019  1.56        32.9
# 3  2018  1.62        32.5
# 4  2017  1.65        31.9

# %%
# yangi mavjud bōlmagan ustun nomi kiritilsa NAN qaytaradi, yani yōq degani
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'])
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.62        32.5  NaN
# 4  2017  1.65        31.9  NaN
# 5  2016  1.66        31.4  NaN
# 6  2015  1.64        30.9  NaN
# 7  2010  1.53        28.5  NaN

# %% [markdown]
# Indekslarni ōzgartirish

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'], index=[21, 20, 19, 18, 17, 16, 15, 10])
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %% [markdown]
# Istalgan ustundagi qiymatni alohida chiqarish usuli

# %%
# birinchi usul
df['Aholi soni']
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
# Series ajratib olish usuli
aholi = df['Aholi soni']
aholi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
# turini kōrish usuli
type(aholi)
# Out:
# pandas.core.series.Series

# %%
# yana bir usuli, agar ustunlar nomi matn kōrinishida bōlsa matnni uzi yoziladi
df.Temp
# Out:
# 21    1.54
# 20    1.48
# 19    1.56
# 18    1.62
# 17    1.65
# 16    1.66
# 15    1.64
# 10    1.53
# Name: Temp, dtype: float64

# %% [markdown]
# Ustunlarni qiymatlarini ōzgartirish

# %%
# hamma qiymatlarni bir songa ōzgartirish
df.YAIM = 0
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9     0
# 20  2020  1.48        33.5     0
# 19  2019  1.56        32.9     0
# 18  2018  1.62        32.5     0
# 17  2017  1.65        31.9     0
# 16  2016  1.66        31.4     0
# 15  2015  1.64        30.9     0
# 10  2010  1.53        28.5     0

# %% [markdown]
# Malum bir qiymatlarni ōzgartirish usuli

# %%
# Series orqali ōzgartirish usuli
val = pd.Series([1700, 1650, 1300], index=[21, 20, 10])
df.YAIM = val
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %% [markdown]
# Barcha qiymatlarni ōzgartirish

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5  1650.0
# 19  2019  1.56        32.9     NaN
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
val = [1700, 1670, 1650, 1590, 1400, 1300, 1350, 1360]
df.YAIM = val
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1650
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360

# %%
# yangi ustun qōshish va filtrlash
df['1500+'] = df.YAIM > 1500
df
# Out:
#      Yil  Temp  Aholi soni  YAIM  1500+
# 21  2021  1.54        33.9  1700   True
# 20  2020  1.48        33.5  1670   True
# 19  2019  1.56        32.9  1650   True
# 18  2018  1.62        32.5  1590   True
# 17  2017  1.65        31.9  1400  False
# 16  2016  1.66        31.4  1300  False
# 15  2015  1.64        30.9  1350  False
# 10  2010  1.53        28.5  1360  False

# %% [markdown]
# Ustunlarni ōchirib tashlash

# %%
del df['1500+']
df
# Out:
#      Yil  Temp  Aholi soni  YAIM  Muslim
# 21  2021  1.54        33.9  1700    1.54
# 20  2020  1.48        33.5  1670    1.48
# 19  2019  1.56        32.9  1650    1.56
# 18  2018  1.62        32.5  1590    1.62
# 17  2017  1.65        31.9  1400    1.65
# 16  2016  1.66        31.4  1300    1.66
# 15  2015  1.64        30.9  1350    1.64
# 10  2010  1.53        28.5  1360    1.53

# %%
del df['Muslim']
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1670
# 19  2019  1.56        32.9  1650
# 18  2018  1.62        32.5  1590
# 17  2017  1.65        31.9  1400
# 16  2016  1.66        31.4  1300
# 15  2015  1.64        30.9  1350
# 10  2010  1.53        28.5  1360
