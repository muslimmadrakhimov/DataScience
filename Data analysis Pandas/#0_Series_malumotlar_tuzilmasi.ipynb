# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### Series malumotlar tuzilmasi

# %%
from pandas import Series # Series malumotlar tuzilmasi

# %%
obj = Series([4, 5, 6, -6.5])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
print(obj)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3   -6.5
# dtype: float64

# %%
obj.values # obyekt ichidagi qiymatlarni kōrish
# Out:
# array([ 4. ,  5. ,  6. , -6.5])

# %%
obj.index # indekslarni kōrish
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# 4.0

# %%
obj2 = Series([6, 3, 2, 1], index=['a', 'b', 'c', 'd'])
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['a']
# Out:
# 6

# %%
obj2[0]
# Out:
# 6

# %%
obj2[['a', 'c', 'd']]
# Out:
# a    6
# c    2
# d    1
# dtype: int64

# %%
obj2[['d', 'd', 'd']]
# Out:
# d    1
# d    1
# d    1
# dtype: int64

# %%
# filtrlash
obj2[obj2>2] # 2dan katta bōlgan qiymatlarni chiqarish
# Out:
# a    6
# b    3
# dtype: int64

# %%
obj2[obj2<3] # 3 dan kichkina bōlgan qiymatlarni chiqarish
# Out:
# c    2
# d    1
# dtype: int64

# %%
obj2 * 2 # har bitta qiymatni 2 ga kōpaytirish
# Out:
# a    12
# b     6
# c     4
# d     2
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    403.428793
# b     20.085537
# c      7.389056
# d      2.718282
# dtype: float64
