# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Lugatdan DataFrame yaratish

# %%
# Lugatdan DataFrame yaratganda lugatdagi kalitlar index ōrnida keladi(2021, 2020 va hokazo...)
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df2 = pd.DataFrame(data)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %% [markdown]
# Indeksga nom berish

# %%
df2.index.name = 'Yil'
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %% [markdown]
# KERAKLI INDEKSLARNI AJRATIB OLISH

# %%
df2 = pd.DataFrame(data, index=[2021, 2019, 2017])
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %% [markdown]
# INDEKSLAR VA USTUNLAR ŌRNINI ALMASHTIRIB QŌYISH USULI

# %%
df2.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
# ikki ōlchovli array kōrinishiga ōtkazish usuli
df2.values
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
# saqlab olish
arr = df2.values
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
# malumotlar turini kōrish
type(arr)
# Out:
# numpy.ndarray
