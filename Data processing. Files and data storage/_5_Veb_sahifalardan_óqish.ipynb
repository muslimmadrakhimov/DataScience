# %% [markdown]
# Web sahifalar
#
# read_html  funksiyasi  internetdagi sahihafalarni barcha jadvallarini kóchirib oladi

# %%
import pandas as pd
import numpy as np

# %%
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
# tashkent degan ózgaruvchini ichida 19 da DataFrame jadvallari bor ekan
len(tashkent)
# Out:
# 19

# %%
# róyhatni chaqirgandaqa chaqiramiz
# 0 chi jadvaldagi DataFrame ni chaqiramiz
tashkent[0]
# Out:
#    Tashkent  ToshkentТашкент, Tachkent, Tashkand, Toshkent  \
# 0                                        Capital city
# 1                                            Tashkent
# 2   .mw-parser-output .tmulti .multiimageinner{dis...
# 3   .mw-parser-output .ib-settlement-cols{text-ali...
# 4                             Nickname: Tosh (A rock)
# 5   Motto(s): Kuch Adolatdadir ("Strength is in Ju...
# 6                  Location of Tashkent in Uzbekistan
# 7                                                 NaN
# 8   .mw-parser-output .locmap .od{position:absolut...
# 9   Coordinates: .mw-parser-output .geo-default,.m...
# 10                                            Country
# 11                                            Settled
# 12                                          Divisions
# 13                                         Government
# 14                                             • Type
# 15                                    • Hakim (Mayor)
# ...

# %%
tashkent[5]
# Out:
#    Climate data for Tashkent (1991–2020, extremes 1867–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6              Average extreme snow depth cm (inches)
# 7                                  Average rainy days
# 8                                  Average snowy days
# 9                       Average relative humidity (%)
# 10                        Mean monthly sunshine hours
# 11                        Source 1: Pogoda.ru.net[54]
# 12                                 Source 2: NOAA[55]
#
#                                                               \
#                             Jan                          Feb
# ...
